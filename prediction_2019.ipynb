# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnasd1007/NSAC-Storytellers/blob/main/prediction_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = '/gdrive/My Drive/spaceapps/'

# %%
data = pd.read_csv(path + 'data.csv')
data.head()
# Out:
#    actual_19  pred_19_18  pred_19_17  pred_19_16  pred_19_15  pred_19_14
# 0     -0.400      -0.278      -0.304      -0.360      -0.346      -0.367
# 1     -0.437      -0.363      -0.370      -0.430      -0.399      -0.413
# 2     -0.406      -0.331      -0.356      -0.410      -0.386      -0.407
# 3     -0.347      -0.355      -0.358      -0.394      -0.360      -0.377
# 4     -0.390      -0.359      -0.346      -0.383      -0.350      -0.362

# %%
corrs=data.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corrs, annot=True)
plt.show()

# %%
import seaborn as sns

# %%
sns.relplot(x="actual_19", y="pred_19_18", ci=None, kind="line", data=data)

# %%
sns.relplot(x="actual_19", y="pred_19_17", ci=None, kind="line", data=data)

# %%
sns.relplot(x="actual_19", y="pred_19_16", ci=None, kind="line", data=data)

# %%
sns.relplot(x="actual_19", y="pred_19_15", ci=None, kind="line", data=data)

# %%
sns.relplot(x="actual_19", y="pred_19_14", ci=None, kind="line", data=data)

# %%
sns.displot(data, x="actual_19", kind="kde", bw_adjust=2)

# %%
sns.displot(data, x="pred_19_18", kind="kde", bw_adjust=2)

# %%
sns.displot(data, x="pred_19_17", kind="kde", bw_adjust=2)

# %%
sns.displot(data, x="pred_19_16", kind="kde", bw_adjust=2)

# %%
sns.displot(data, x="pred_19_15", kind="kde", bw_adjust=2)

# %%
sns.displot(data, x="pred_19_14", kind="kde", bw_adjust=2)
