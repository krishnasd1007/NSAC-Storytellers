# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnasd1007/NSAC-Storytellers/blob/main/2017.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = '/gdrive/My Drive/spaceapps/'

# %% [markdown]
# ##**DATA PROCESSING**

# %%
data = pd.read_csv(path + '2017.csv')
data.head()
# Out:
#        STATION        DATE   LATITUDE  ...  PRCP_ATTRIBUTES   SNDP FRSHTT
# 0  43295099999  2017-01-01  12.966667  ...                I  999.9      0
# 1  43295099999  2017-01-02  12.966667  ...                I  999.9      0
# 2  43295099999  2017-01-03  12.966667  ...                I  999.9      0
# 3  43295099999  2017-01-04  12.966667  ...                I  999.9      0
# 4  43295099999  2017-01-05  12.966667  ...                I  999.9      0
#
# [5 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'NAME', 'TEMP',
#        'TEMP_ATTRIBUTES', 'DEWP', 'DEWP_ATTRIBUTES', 'SLP', 'SLP_ATTRIBUTES',
#        'STP', 'STP_ATTRIBUTES', 'VISIB', 'VISIB_ATTRIBUTES', 'WDSP',
#        'WDSP_ATTRIBUTES', 'MXSPD', 'GUST', 'MAX', 'MAX_ATTRIBUTES', 'MIN',
#        'MIN_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES', 'SNDP', 'FRSHTT'],
#       dtype='object')

# %%
data = data.drop(columns=['STATION','NAME','TEMP_ATTRIBUTES','SLP_ATTRIBUTES','STP_ATTRIBUTES','GUST','VISIB_ATTRIBUTES','WDSP_ATTRIBUTES','DEWP_ATTRIBUTES','MAX_ATTRIBUTES','MIN_ATTRIBUTES','PRCP_ATTRIBUTES'])

# %%
data.head(10)
# Out:
#          DATE   LATITUDE  LONGITUDE  ELEVATION  ...   MIN  PRCP   SNDP  FRSHTT
# 0  2017-01-01  12.966667  77.583333      921.0  ...  58.3   0.0  999.9       0
# 1  2017-01-02  12.966667  77.583333      921.0  ...  62.6   0.0  999.9       0
# 2  2017-01-03  12.966667  77.583333      921.0  ...  61.0   0.0  999.9       0
# 3  2017-01-04  12.966667  77.583333      921.0  ...  60.4   0.0  999.9       0
# 4  2017-01-05  12.966667  77.583333      921.0  ...  59.9   0.0  999.9       0
# 5  2017-01-06  12.966667  77.583333      921.0  ...  60.8   0.0  999.9       0
# 6  2017-01-07  12.966667  77.583333      921.0  ...  60.8   0.0  999.9       0
# 7  2017-01-08  12.966667  77.583333      921.0  ...  60.8   0.0  999.9       0
# 8  2017-01-09  12.966667  77.583333      921.0  ...  59.0   0.0  999.9       0
# 9  2017-01-10  12.966667  77.583333      921.0  ...  60.8   0.0  999.9       0
#
# [10 rows x 16 columns]

# %%
data.isnull()
# Out:
#       DATE  LATITUDE  LONGITUDE  ELEVATION  ...    MIN   PRCP   SNDP  FRSHTT
# 0    False     False      False      False  ...  False  False  False   False
# 1    False     False      False      False  ...  False  False  False   False
# 2    False     False      False      False  ...  False  False  False   False
# 3    False     False      False      False  ...  False  False  False   False
# 4    False     False      False      False  ...  False  False  False   False
# ..     ...       ...        ...        ...  ...    ...    ...    ...     ...
# 360  False     False      False      False  ...  False  False  False   False
# 361  False     False      False      False  ...  False  False  False   False
# 362  False     False      False      False  ...  False  False  False   False
# 363  False     False      False      False  ...  False  False  False   False
# 364  False     False      False      False  ...  False  False  False   False
#
# [365 rows x 16 columns]

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
data['MONTH'] = pd.to_datetime(data.DATE, format='%Y/%m/%d').dt.month_name()

# %%
data.head()
# Out:
#          DATE   LATITUDE  LONGITUDE  ELEVATION  ...  PRCP   SNDP  FRSHTT    MONTH
# 0  2017-01-01  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 1  2017-01-02  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 2  2017-01-03  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 3  2017-01-04  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 4  2017-01-05  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
#
# [5 rows x 17 columns]

# %%
data = data.drop(columns='DATE')
data.head()
# Out:
#     LATITUDE  LONGITUDE  ELEVATION  TEMP  ...  PRCP   SNDP  FRSHTT    MONTH
# 0  12.966667  77.583333      921.0  69.8  ...   0.0  999.9       0  January
# 1  12.966667  77.583333      921.0  70.9  ...   0.0  999.9       0  January
# 2  12.966667  77.583333      921.0  72.1  ...   0.0  999.9       0  January
# 3  12.966667  77.583333      921.0  71.2  ...   0.0  999.9       0  January
# 4  12.966667  77.583333      921.0  71.5  ...   0.0  999.9       0  January
#
# [5 rows x 16 columns]

# %%
mnth_list = data['MONTH'].tolist() 
print(mnth_list)
# Out:
# ['January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'April', 'April', 'April', 'April', 'Apri
# ...

# %%
months = {'MONTH': {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12}}

# %%
data.replace(months, inplace=True)
data.head()
# Out:
#     LATITUDE  LONGITUDE  ELEVATION  TEMP  ...  PRCP   SNDP  FRSHTT  MONTH
# 0  12.966667  77.583333      921.0  69.8  ...   0.0  999.9       0      1
# 1  12.966667  77.583333      921.0  70.9  ...   0.0  999.9       0      1
# 2  12.966667  77.583333      921.0  72.1  ...   0.0  999.9       0      1
# 3  12.966667  77.583333      921.0  71.2  ...   0.0  999.9       0      1
# 4  12.966667  77.583333      921.0  71.5  ...   0.0  999.9       0      1
#
# [5 rows x 16 columns]

# %% [markdown]
# ##**PLOTS**

# %%
sns.relplot(x="DEWP", y="TEMP", ci=None, kind="line", data=data)

# %%
sns.relplot(x="SLP", y="TEMP", ci=None, kind="line", data=data)

# %%
sns.relplot(x="VISIB", y="TEMP", ci=None, kind="line", data=data)

# %%
sns.relplot(x="WDSP", y="TEMP", ci=None, kind="line", data=data)

# %%
sns.relplot(x="DEWP", y="TEMP", hue="MONTH",kind="line", data=data)

# %%
sns.relplot(x="SLP", y="TEMP", hue="MONTH",kind="line", data=data)

# %%
sns.relplot(x="STP", y="TEMP", hue="MONTH",kind="line", data=data)

# %%
sns.relplot(x="VISIB", y="TEMP", hue="MONTH",kind="line", data=data)

# %%
sns.relplot(x="WDSP", y="TEMP", hue="MONTH",kind="line", data=data)

# %%
data = data.drop(columns=['LATITUDE','LONGITUDE','ELEVATION','SLP','SNDP'])
data.head()
# Out:
#    TEMP  DEWP    STP  VISIB  WDSP  MXSPD   MAX   MIN  PRCP  FRSHTT  MONTH
# 0  69.8  56.0  911.4    3.7   1.2    1.9  81.7  58.3   0.0       0      1
# 1  70.9  56.0  911.9    4.2   1.1    1.9  81.9  62.6   0.0       0      1
# 2  72.1  51.6  911.4    4.3   1.5    1.9  84.2  61.0   0.0       0      1
# 3  71.2  53.8  911.0    4.2   1.6    1.9  85.1  60.4   0.0       0      1
# 4  71.5  54.7  910.5    3.7   1.2    1.9  84.2  59.9   0.0       0      1

# %%
corrs=data.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corrs, annot=True)
plt.show()

# %% [markdown]
# ##**ML MODEL**

# %%
data = (data-data.mean())/(data.max()-data.min())
data.head()
# Out:
#        TEMP      DEWP       STP  ...      PRCP    FRSHTT     MONTH
# 0 -0.318394 -0.201994  0.227375  ... -0.010038 -0.038926 -0.502366
# 1 -0.259571 -0.201994  0.267698  ... -0.010038 -0.038926 -0.502366
# 2 -0.195400 -0.351654  0.227375  ... -0.010038 -0.038926 -0.502366
# 3 -0.243528 -0.276824  0.195117  ... -0.010038 -0.038926 -0.502366
# 4 -0.227485 -0.246212  0.154795  ... -0.010038 -0.038926 -0.502366
#
# [5 rows x 11 columns]

# %%
x = data.drop(columns=['TEMP'])
y = data['TEMP']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(x_train,y_train)

# %%
train_pred = model.predict(x_train)
test_pred = model.predict(x_test)

score = model.score(x_train,y_train)
print('train model score : {} %'.format(score*100))

score = model.score(x_test,y_test)
print('test model score : {} %'.format(score*100))
# Out:
# train model score : 92.39681779711583 %
# test model score : 90.11985411151727 %

# %%
from sklearn.metrics import mean_absolute_error

train_error = mean_absolute_error(y_train, train_pred)
train_accuracy = 1 - train_error
print('accuracy on train data : {} %'.format(train_accuracy*100))

test_error = mean_absolute_error(y_test,test_pred)
test_accuracy = 1 - test_error
print('accuracy on test data : {} %'.format(test_accuracy*100))
# Out:
# accuracy on train data : 95.25637908352658 %
# accuracy on test data : 94.66315379016443 %

# %% [markdown]
# ##**2018 PREDICTION**

# %%
datat = pd.read_csv(path + '2019.csv')

# %%
datat = datat.drop(columns=['STATION','NAME','TEMP_ATTRIBUTES','SLP_ATTRIBUTES','STP_ATTRIBUTES','GUST','VISIB_ATTRIBUTES','WDSP_ATTRIBUTES','DEWP_ATTRIBUTES','MAX_ATTRIBUTES','MIN_ATTRIBUTES','PRCP_ATTRIBUTES'])

# %%
datat['MONTH'] = pd.to_datetime(datat.DATE, format='%Y/%m/%d').dt.month_name()

# %%
datat = datat.drop(columns='DATE')

# %%
monthst = {'MONTH': {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12}}

# %%
datat.replace(monthst, inplace=True)

# %%
datat = (datat-datat.mean())/(datat.max()-datat.min())

# %%
x = datat.drop(columns=['TEMP','LATITUDE','LONGITUDE','ELEVATION','SLP','SNDP'])
x.head()
# Out:
#        DEWP       STP     VISIB  ...      PRCP    FRSHTT     MONTH
# 0 -0.597885  0.478506  0.086301  ... -0.009234 -0.041653 -0.502366
# 1 -0.567684  0.505778  0.055051  ... -0.009234 -0.041653 -0.502366
# 2 -0.618020  0.523960  0.023801  ... -0.009234 -0.041653 -0.502366
# 3 -0.470369  0.469415 -0.132449  ... -0.009234 -0.041653 -0.502366
# 4 -0.346208  0.333051 -0.132449  ... -0.009234 -0.041653 -0.502366
#
# [5 rows x 10 columns]

# %%
datat_pred = model.predict(x)
print(datat_pred)
# Out:
# [-0.30431681 -0.37042373 -0.3558374  -0.35779688 -0.34629348 -0.48246378
#  -0.2857994  -0.20362651 -0.26103289 -0.20146068 -0.25604912 -0.21494385
#  -0.28586712 -0.22042202 -0.29141526 -0.22651318 -0.16147074 -0.18566342
#  -0.24331226 -0.22225151 -0.23220406 -0.45114291 -0.18850215 -0.11493579
#  -0.11670405 -0.08540917 -0.0716599  -0.02194283 -0.1461897  -0.2146472
#  -0.18433258 -0.25993638 -0.26639593 -0.16763191 -0.16303823 -0.0632382
#  -0.09552533 -0.01712964  0.0826033   0.06663955 -0.03585266 -0.05944169
#  -0.21439076 -0.15538251 -0.07852691 -0.00198028  0.0873721   0.20949247
#   0.08545586  0.2309415   0.13154542  0.00391844  0.02386281 -0.00441485
#   0.0960996   0.15531959  0.25898458  0.26838258  0.22269908  0.16324205
#   0.20930863  0.09321032  0.14398022  0.30509843  0.37965307  0.38056226
#   0.44088361  0.35215176  0.29062791  0.33722865  0.30397061  0.20523723
#   0.2179405   0.26096759  0.19604412  0.140446    0.2270584   0.25171447
# ...

# %%
path = '/gdrive/My Drive/spaceapps/'
np.savetxt(path + "/2019_pred_2017.csv",datat_pred, delimiter=",")

# %%
datat_pred.mean()
# Out:
# -4.3700851403761436e-05

# %%
y.mean()
# Out:
# -3.588149564381003e-15
