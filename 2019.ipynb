# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnasd1007/NSAC-Storytellers/blob/main/2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = '/gdrive/My Drive/spaceapps/'

# %%
data = pd.read_csv(path + '2019.csv')
data.head()
# Out:
#        STATION        DATE   LATITUDE  ...  PRCP_ATTRIBUTES   SNDP FRSHTT
# 0  43295099999  2019-01-01  12.966667  ...                I  999.9      0
# 1  43295099999  2019-01-02  12.966667  ...                I  999.9      0
# 2  43295099999  2019-01-03  12.966667  ...                I  999.9      0
# 3  43295099999  2019-01-04  12.966667  ...                I  999.9      0
# 4  43295099999  2019-01-05  12.966667  ...                I  999.9      0
#
# [5 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'NAME', 'TEMP',
#        'TEMP_ATTRIBUTES', 'DEWP', 'DEWP_ATTRIBUTES', 'SLP', 'SLP_ATTRIBUTES',
#        'STP', 'STP_ATTRIBUTES', 'VISIB', 'VISIB_ATTRIBUTES', 'WDSP',
#        'WDSP_ATTRIBUTES', 'MXSPD', 'GUST', 'MAX', 'MAX_ATTRIBUTES', 'MIN',
#        'MIN_ATTRIBUTES', 'PRCP', 'PRCP_ATTRIBUTES', 'SNDP', 'FRSHTT'],
#       dtype='object')

# %%
data = data.drop(columns='STATION')
data = data.drop(columns='NAME')
data = data.drop(columns='TEMP_ATTRIBUTES')
data = data.drop(columns='SLP_ATTRIBUTES')
data = data.drop(columns='STP_ATTRIBUTES')
data = data.drop(columns='VISIB_ATTRIBUTES')
data = data.drop(columns='WDSP_ATTRIBUTES')
data = data.drop(columns='DEWP_ATTRIBUTES')
data = data.drop(columns='MAX_ATTRIBUTES')
data = data.drop(columns='MIN_ATTRIBUTES')
data = data.drop(columns='PRCP_ATTRIBUTES')

# %%
data.head(10)
# Out:
#          DATE   LATITUDE  LONGITUDE  ELEVATION  ...   MIN  PRCP   SNDP  FRSHTT
# 0  2019-01-01  12.966667  77.583333      921.0  ...  57.2   0.0  999.9       0
# 1  2019-01-02  12.966667  77.583333      921.0  ...  54.3   0.0  999.9       0
# 2  2019-01-03  12.966667  77.583333      921.0  ...  55.6   0.0  999.9       0
# 3  2019-01-04  12.966667  77.583333      921.0  ...  55.9   0.0  999.9       0
# 4  2019-01-05  12.966667  77.583333      921.0  ...  56.5   0.0  999.9       0
# 5  2019-01-06  12.966667  77.583333      921.0  ...  58.5   0.0  999.9  100000
# 6  2019-01-07  12.966667  77.583333      921.0  ...  58.5   0.0  999.9       0
# 7  2019-01-08  12.966667  77.583333      921.0  ...  59.4   0.0  999.9       0
# 8  2019-01-09  12.966667  77.583333      921.0  ...  55.8   0.0  999.9       0
# 9  2019-01-10  12.966667  77.583333      921.0  ...  58.1   0.0  999.9       0
#
# [10 rows x 17 columns]

# %%
data.isnull()
# Out:
#       DATE  LATITUDE  LONGITUDE  ELEVATION  ...    MIN   PRCP   SNDP  FRSHTT
# 0    False     False      False      False  ...  False  False  False   False
# 1    False     False      False      False  ...  False  False  False   False
# 2    False     False      False      False  ...  False  False  False   False
# 3    False     False      False      False  ...  False  False  False   False
# 4    False     False      False      False  ...  False  False  False   False
# ..     ...       ...        ...        ...  ...    ...    ...    ...     ...
# 360  False     False      False      False  ...  False  False  False   False
# 361  False     False      False      False  ...  False  False  False   False
# 362  False     False      False      False  ...  False  False  False   False
# 363  False     False      False      False  ...  False  False  False   False
# 364  False     False      False      False  ...  False  False  False   False
#
# [365 rows x 17 columns]

# %%
sns.heatmap(data.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
data['MONTH'] = pd.to_datetime(data.DATE, format='%Y/%m/%d').dt.month_name()

# %%
data.head()
# Out:
#          DATE   LATITUDE  LONGITUDE  ELEVATION  ...  PRCP   SNDP  FRSHTT    MONTH
# 0  2019-01-01  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 1  2019-01-02  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 2  2019-01-03  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 3  2019-01-04  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
# 4  2019-01-05  12.966667  77.583333      921.0  ...   0.0  999.9       0  January
#
# [5 rows x 18 columns]

# %%
data = data.drop(columns='DATE')
data.head()
# Out:
#     LATITUDE  LONGITUDE  ELEVATION  TEMP  ...  PRCP   SNDP  FRSHTT    MONTH
# 0  12.966667  77.583333      921.0  68.5  ...   0.0  999.9       0  January
# 1  12.966667  77.583333      921.0  67.8  ...   0.0  999.9       0  January
# 2  12.966667  77.583333      921.0  68.4  ...   0.0  999.9       0  January
# 3  12.966667  77.583333      921.0  69.5  ...   0.0  999.9       0  January
# 4  12.966667  77.583333      921.0  68.7  ...   0.0  999.9       0  January
#
# [5 rows x 17 columns]

# %%
mnth_list = data['MONTH'].tolist() 
print(mnth_list)
# Out:
# ['January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'January', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'February', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'March', 'April', 'April', 'April', 'April', 'Apri
# ...

# %%
months = {'MONTH': {'January':1,'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9,'October':10,'November':11,'December':12}}

# %%
data.replace(months, inplace=True)
data.head()
# Out:
#     LATITUDE  LONGITUDE  ELEVATION  TEMP  ...  PRCP   SNDP  FRSHTT  MONTH
# 0  12.966667  77.583333      921.0  68.5  ...   0.0  999.9       0      1
# 1  12.966667  77.583333      921.0  67.8  ...   0.0  999.9       0      1
# 2  12.966667  77.583333      921.0  68.4  ...   0.0  999.9       0      1
# 3  12.966667  77.583333      921.0  69.5  ...   0.0  999.9       0      1
# 4  12.966667  77.583333      921.0  68.7  ...   0.0  999.9       0      1
#
# [5 rows x 17 columns]
